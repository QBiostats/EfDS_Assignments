# %% [markdown]
# # My first document
# I am learning Python

# %% [markdown]
# ## Integer numbers

# %%
15 + 25
# Out:
# 40

# %%
type(15)
# Out:
# int

# %%
1_000_000
# Out:
# 1000000

# %% [markdown]
# ## Real numbers

# %%
1.
# Out:
# 1.0

# %%
type(1.)
# Out:
# float

# %% [markdown]
# ## Arithmetic

# %%
10/7
# Out:
# 1.4285714285714286

# %%
10//7
# Out:
# 1

# %%
10%7      # remainder of 10 divided by 7 is 3
# Out:
# 3

# %%
10%7     # TODO:check this
# Out:
# 3

# %% [markdown]
# ## Texts (strings)

# %%
"Statistics and Data Science"   # double quotes
# Out:
# 'Statistics and Data Science'

# %%
'Statistics and Data Science'    #single quotes
# Out:
# 'Statistics and Data Science'

# %%
'"Statstics" and Data Science"'
# Out:
# '"Statstics" and Data Science"'

# %%
''' 
This is a multi-line comment. 
You can write anything here, and it will not affect the code execution.
'''
# Out:
# ' \nThis is a multi-line comment. \nYou can write anything here, and it will not affect the code execution.\n'

# %%
''' This is a multi-line comment. 
You can write anything here, and it will not affect the code execution.'''
# Out:
# ' This is a multi-line comment. \nYou can write anything here, and it will not affect the code execution.'

# %%
type("Hello")
# Out:
# str

# %%
"Hello" + 3*" World"
# Out:
# 'Hello World World World'

# %% [markdown]
# ## Variables

# %%
roomWidth = 10
roomlength = 15
roomArea = roomWidth * roomlength
roomArea
# Out:
# 150

# %%
roomWidth, roomlength = 20, 30

# %%
#a, b=b, a

# %%
cnt=0
cnt
# Out:
# 0

# %%
cnt = cnt + 1 #+= *= /= -=
cnt
# Out:
# 7

# %%
cnt += 1
cnt
# Out:
# 8

# %% [markdown]
# ## Logicals

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
x = 10

# %%
x > 5
# Out:
# True

# %%
x >= 10
# Out:
# True

# %%
x == 10
# Out:
# True

# %%
x != 5 # different than
# Out:
# True

# %%
x > 5 and x < 15
# Out:
# True

# %%
x < 5 or x > 15
# Out:
# False

# %% [markdown]
# ## Lists

# %%
kcs = [2450, 2100, 2200, 1800, 1900] #list
kcs
# Out:
# [2450, 2100, 2200, 1800, 1900]

# %%
print(kcs)
# Out:
# [2450, 2100, 2200, 1800, 1900]

# %%
kcs[2] = 1999 #third observation, 2200
kcs
# Out:
# [2450, 2100, 1999, 1800, 1900]

# %%
len(kcs)
# Out:
# 5

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
days
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
a = ["Monday", 2200]

# %% [markdown]
# ## Tuples

# %%
days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday") #immutable object.

# %%
days[2] = "TUESDAY"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 days[2] = "TUESDAY"
#
# TypeError: 'tuple' object does not support item assignment

# %%
(1+2)*3
# Out:
# 9

# %%
1 #number one
(1) #number one

(1,) #tuple with one element
# Out:
# (1,)

# %%
x =() #empty tuple
type(x)
# Out:
# tuple

# %% [markdown]
# ## Accessing multiple list / tuple elements

# %%
kcs = [2450, 2100, 2200, 1800, 1900]

# %%
kcs[2:4] # element 4 is not included, thus only elements 2 and 3 are shown
# Out:
# [2200, 1800]

# %%
kcs[2:] #from element 2 to the end
# Out:
# [2200, 1800, 1900]

# %%
kcs[:3] #from the beginning to element 3 (not included)
# Out:
# [2450, 2100, 2200]

# %%
kcs[1:3] = [1,2]
kcs
# Out:
# [2450, 1, 2, 1800, 1900]

# %%
kcs[1:3] = [100,101,102,103,104]
kcs
# Out:
# [2450, 100, 101, 102, 103, 104, 102, 103, 104, 1800, 1900]

# %% [markdown]
# ## Deep and shallow copy

# %%
v = [1,2,3]
v
# Out:
# [1, 2, 3]

# %%
w=v # shallow copy
w
# Out:
# [1, 2, 3]

# %%
v[0] = 100
v
# Out:
# [100, 2, 3]

# %%
w
# Out:
# [100, 2, 3]

# %% [markdown]
# ## List comprehensions

# %%
nums = [1, -2,3, -4,5]

# %%
[n*n for n in nums] # [ ] puts it in a list
# Out:
# [1, 4, 9, 16, 25]

# %%
[n*n for n in nums if n > 0]
# Out:
# [1, 9, 25]
