# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.3'

# %%
arr = np.array([[1,2,3], [4,5,6]])
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr.reshape((3,2))
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
arr2d = np.zeros((3,2), dtype = np.int32)
arr2d.dtype
# Out:
# dtype('int32')

# %%
np.ones((3,2), dtype="f2")
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]], dtype=float16)

# %%
np.arange(5,10, dtype="f2")
# Out:
# array([5., 6., 7., 8., 9.], dtype=float16)

# %%
arr2c = np.arange(4).reshape((2,2))
arr2c
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
arr = np.arange(4)
np.repeat(arr,2)
np.tile(arr,2)
# Out:
# array([0, 1, 2, 3, 0, 1, 2, 3])

# %%
arr2c.shape
# Out:
# (2, 2)

# %%
rng = np.random.default_rng(12345)
rng.integers(0,10,2*2).reshape(2,2)
# Out:
# array([[6, 2],
#        [7, 3]])

# %%
arr2d = rng.integers(0,10,4*5).reshape(4,5)
np.mean(arr2d)
# Out:
# np.float64(4.5)

# %%
np.mean(arr2d, axis=0) # mean based on the rows, so we get the mean for each column
# Out:
# array([5.25, 2.25, 5.5 , 5.25, 4.25])

# %%
arrb = arr <2
arrb
# Out:
# array([ True,  True, False, False])

# %%
arrb.dtype
# Out:
# dtype('bool')

# %%
arrb.all()
# Out:
# np.False_

# %%
arrb.any()
# Out:
# np.True_

# %%
arr1d = np.array([2,2,2,2])
arr1d
# Out:
# array([2, 2, 2, 2])

# %%
arr2d = np.arange(8).reshape(2,4)
arr2d
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
arr1d + arr2d
# Out:
# array([[2, 3, 4, 5],
#        [6, 7, 8, 9]])

# %%
arr3d = np.arange(8).reshape(2,2,2)
arr3d
# Out:
# array([[[0, 1],
#         [2, 3]],
#
#        [[4, 5],
#         [6, 7]]])

# %%
p1,p2 = arr3d

# %%
print(p1)
# Out:
# [[0 1]
#  [2 3]]

# %%
v0, v1 = p1
print(v0)
# Out:
# [0 1]
