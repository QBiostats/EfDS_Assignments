# %%
# !pip install jupysql
# Out:
# Requirement already satisfied: jupysql in c:\users\qstef\anaconda3\lib\site-packages (0.11.1)
# Requirement already satisfied: prettytable>=3.12.0 in c:\users\qstef\anaconda3\lib\site-packages (from jupysql) (3.17.0)
# Requirement already satisfied: sqlalchemy in c:\users\qstef\anaconda3\lib\site-packages (from jupysql) (2.0.30)
# Requirement already satisfied: sqlparse in c:\users\qstef\anaconda3\lib\site-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\qstef\anaconda3\lib\site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\qstef\anaconda3\lib\site-packages (from jupysql) (3.1.4)
# Requirement already satisfied: sqlglot>=11.3.7 in c:\users\qstef\anaconda3\lib\site-packages (from jupysql) (30.4.2)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in c:\users\qstef\anaconda3\lib\site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in c:\users\qstef\anaconda3\lib\site-packages (from jupysql) (0.2.27)
# Requirement already satisfied: pyyaml in c:\users\qstef\anaconda3\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.1)
# Requirement already satisfied: posthog>=3.0 in c:\users\qstef\anaconda3\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (7.11.0)
# Requirement already satisfied: wcwidth in c:\users\qstef\anaconda3\lib\site-packages (from prettytable>=3.12.0->jupysql) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\qstef\anaconda3\lib\site-packages (from jinja2->jupysql) (2.1.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\qstef\anaconda3\lib\site-packages (from sqlalchemy->jupysql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\qstef\anaconda3\lib\site-packages (from sqlalchemy->jupysql) (3.0.1)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\qstef\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.2)
# Requirement already satisfied: six>=1.5 in c:\users\qstef\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\qstef\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\qstef\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\qstef\anaconda3\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\qstef\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\qstef\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\qstef\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\qstef\anaconda3\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2026.1.4)

# %%
import urllib.request
import shutil

# %%
url = "https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip"
opener = urllib.request.build_opener()
opener.addheaders = [('User-Agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)

urllib.request.urlretrieve(url, "chinook.zip")
# Out:
# ('chinook.zip', <http.client.HTTPMessage at 0x2a6fa4ded70>)

# %%
shutil.unpack_archive("chinook.zip")

# %%
import urllib.request    # needed for download of the example database
import shutil            # needed for unzipping of the example database

import sqlalchemy as sa
import pandas as pd

# %%
# %pip install jupysql
# Out:
# Collecting jupysql
#   Using cached jupysql-0.11.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: prettytable>=3.12.0 in c:\users\qstef\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupysql) (3.17.0)
# Requirement already satisfied: sqlalchemy in c:\users\qstef\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupysql) (1.4.54)
# Requirement already satisfied: sqlparse in c:\users\qstef\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\qstef\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jupysql) (0.2.0)
# Collecting jinja2 (from jupysql)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting sqlglot>=11.3.7 (from jupysql)
#   Using cached sqlglot-30.4.2-py3-none-any.whl.metadata (24 kB)
# Collecting jupysql-plugin>=0.4.2 (from jupysql)
#   Using cached jupysql_plugin-0.4.5-py3-none-any.whl.metadata (7.8 kB)
# Collecting ploomber-core>=0.2.7 (from jupysql)
#   Using cached ploomber_core-0.2.27-py3-none-any.whl.metadata (532 bytes)
# Collecting pyyaml (from ploomber-core>=0.2.7->jupysql)
#   Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# Collecting posthog>=3.0 (from ploomber-core>=0.2.7->jupysql)
#   Using cached posthog-7.11.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting requests<3.0,>=2.7 (from posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\qstef\appdata\roaming\python\python314\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\qstef\appdata\roaming\python\python314\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\qstef\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (4.15.0)
# Collecting charset_normalizer<4,>=2 (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading charset_normalizer-3.4.7-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.26 (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wcwidth in c:\users\qstef\appdata\roaming\python\python314\site-packages (from prettytable>=3.12.0->jupysql) (0.5.3)
# Collecting MarkupSafe>=2.0 (from jinja2->jupysql)
#   Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\qstef\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sqlalchemy->jupysql) (3.4.0)
# Using cached jupysql-0.11.1-py3-none-any.whl (95 kB)
# Using cached jupysql_plugin-0.4.5-py3-none-any.whl (192 kB)
# Using cached ploomber_core-0.2.27-py3-none-any.whl (22 kB)
# Using cached posthog-7.11.0-py3-none-any.whl (219 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp314-cp314-win_amd64.whl (159 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached sqlglot-30.4.2-py3-none-any.whl (670 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl (15 kB)
# Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl (156 kB)
# Installing collected packages: urllib3, sqlglot, pyyaml, MarkupSafe, idna, distro, charset_normalizer, certifi, backoff, requests, jinja2, posthog, ploomber-core, jupysql-plugin, jupysql
#
#    -- -------------------------------------  1/15 [sqlglot]
#    -- -------------------------------------  1/15 [sqlglot]
#    -- -------------------------------------  1/15 [sqlglot]
#    -- -------------------------------------  1/15 [sqlglot]
#    -- -------------------------------------  1/15 [sqlglot]
#    -- -------------------------------------  1/15 [sqlglot]
#    ----- ----------------------------------  2/15 [pyyaml]
#    ---------- -----------------------------  4/15 [idna]
#    --------------------- ------------------  8/15 [backoff]
#    -------------------------- ------------- 10/15 [jinja2]
#    ----------------------------- ---------- 11/15 [posthog]
#    ----------------------------- ---------- 11/15 [posthog]
#    ----------------------------- ---------- 11/15 [posthog]
#    ---------------------------------- ----- 13/15 [jupysql-plugin]
#    ------------------------------------- -- 14/15 [jupysql]
#    ---------------------------------------- 15/15 [jupysql]
#
# Successfully installed MarkupSafe-3.0.3 backoff-2.2.1 certifi-2026.2.25 charset_normalizer-3.4.7 distro-1.9.0 idna-3.11 jinja2-3.1.6 jupysql-0.11.1 jupysql-plugin-0.4.5 ploomber-core-0.2.27 posthog-7.11.0 pyyaml-6.0.3 requests-2.33.1 sqlglot-30.4.2 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script distro.exe is installed in 'c:\Users\qstef\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\qstef\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# Connecting to 'sqlite:///chinook.db'

# %%
engine = sa.create_engine("sqlite:///chinook.db")

# %%
sql = sa.text("SELECT * FROM albums LIMIT 5")
with engine.connect() as conn:
    arr = conn.execute(sql).fetchall()
arr
# Out:
# [(1, 'For Those About To Rock We Salute You', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Restless and Wild', 2),
#  (4, 'Let There Be Rock', 1),
#  (5, 'Big Ones', 3)]

# %%
# %sql SELECT * FROM albums LIMIT 5
# Out:
# Running query in 'sqlite:///chinook.db'
# +---------+---------------------------------------+----------+
# | AlbumId |                 Title                 | ArtistId |
# +---------+---------------------------------------+----------+
# |    1    | For Those About To Rock We Salute You |    1     |
# |    2    |           Balls to the Wall           |    2     |
# |    3    |           Restless and Wild           |    2     |
# |    4    |           Let There Be Rock           |    1     |
# |    5    |                Big Ones               |    3     |
# +---------+---------------------------------------+----------+

# %%
res = %sql SELECT * FROM albums LIMIT 5
df = res.DataFrame()
df
# Out:
# Running query in 'sqlite:///chinook.db'
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
# %%sql
# SELECT trackid, composer, unitprice FROM tracks LIMIT 5
# Out:
# Running query in 'sqlite:///chinook.db'
# +---------+------------------------------------------------------------------------+-----------+
# | TrackId |                                Composer                                | UnitPrice |
# +---------+------------------------------------------------------------------------+-----------+
# |    1    |               Angus Young, Malcolm Young, Brian Johnson                |    0.99   |
# |    2    |                                  None                                  |    0.99   |
# |    3    |          F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman           |    0.99   |
# |    4    | F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman |    0.99   |
# |    5    |                       Deaffy & R.A. Smith-Diesel                       |    0.99   |
# +---------+------------------------------------------------------------------------+-----------+
